# %%
import torch.nn.functional as F
import torch.nn as nn
from torch import optim
import torch
import spacy

# from torchtext.legacy import data,datasets
from torchtext import *
import torchtext 

print(torch.cuda.is_available())
print(spacy.require_gpu())
# Out:
# True
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#       9 import torchtext
#      11 print(torch.cuda.is_available())
# ---> 12 print(spacy.require_gpu())
#
# File ~/.local/lib/python3.8/site-packages/thinc/util.py:212, in require_gpu(gpu_id)
#     209 from .backends import set_current_ops, CupyOps
#     211 if CupyOps.xp is None:
# --> 212     raise ValueError("GPU is not accessible. Was the library installed correctly?")
#     214 set_current_ops(CupyOps())
#     215 set_active_gpu(gpu_id)
#
# ValueError: GPU is not accessible. Was the library installed correctly?

# %%
# nlp = spacy.load("en_core_web_sm")

TEXT = data.Field(lower=True, include_lengths=True, batch_first=False, tokenize='spacy')
LABEL = data.LabelField()

train,test = datasets.IMDB.splits(TEXT, LABEL)
TEXT.build_vocab(train, vectors='glove.6B.100d')

LABEL.build_vocab(train)

train_iter, test_iter = data.BucketIterator.splits((train,test), batch_sizes=(128,1024), device = torch.device("cuda"), sort_within_batch=True, repeat=False)
# Out:
# /home/sky3alfory/.local/lib/python3.8/site-packages/torchtext/data/utils.py:123: UserWarning: Spacy model "en" could not be loaded, trying "en_core_web_sm" instead
#   warnings.warn(f'Spacy model "{language}" could not be loaded, trying "{OLD_MODEL_SHORTCUTS[language]}" instead')
# Please install SpaCy and the SpaCy en tokenizer. See the docs at https://spacy.io for more information.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/torchtext/data/utils.py:115, in get_tokenizer(tokenizer, language)
#     114 try:
# --> 115     spacy = spacy.load(language)
#     116 except IOError:
#     117     # Model shortcuts no longer work in spaCy 3.0+, try using fullnames
#     118     # List is from https://github.com/explosion/spaCy/blob/b903de3fcb56df2f7247e5b6cfa6b66f4ff02b62/spacy/errors.py#L789
#
# File ~/.local/lib/python3.8/site-packages/spacy/__init__.py:47, in load(name, disable, exclude, config)
#      35 """Load a spaCy model from an installed package or a local path.
#      36
#      37 name (str): Package name or model path.
#    (...)
#      45 RETURNS (Language): The loaded nlp object.
#      46 """
# ---> 47 return util.load_model(name, disable=disable, exclude=exclude, config=config)
#
# File ~/.local/lib/python3.8/site-packages/spacy/util.py:328, in load_model(name, vocab, disable, exclude, config)
#     327 if name in OLD_MODEL_SHORTCUTS:
# --> 328     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))
#     329 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E941] Can't find model 'en'. It looks like you're trying to load a model from a shortcut, which is deprecated as of spaCy v3.0. To load the model, use its full name instead:
#
# nlp = spacy.load("en_core_web_sm")
#
# For more details on the available models, see the models directory: https://spacy.io/models. If you want to create a blank model, use spacy.blank: nlp = spacy.blank("en")
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 3
#       1 # nlp = spacy.load("en_core_web_sm")
# ----> 3 TEXT = legacy.data.Field(lower=True, include_lengths=True, batch_first=False, tokenize='spacy')
#       4 LABEL = data.LabelField()
#       6 train,test = datasets.IMDB.splits(TEXT, LABEL)
#
# File ~/.local/lib/python3.8/site-packages/torchtext/legacy/data/field.py:161, in Field.__init__(self, sequential, use_vocab, init_token, eos_token, fix_length, dtype, preprocessing, postprocessing, lower, tokenize, tokenizer_language, include_lengths, batch_first, pad_token, unk_token, pad_first, truncate_first, stop_words, is_target)
#     158 # store params to construct tokenizer for serialization
#     159 # in case the tokenizer isn't picklable (e.g. spacy)
#     160 self.tokenizer_args = (tokenize, tokenizer_language)
# --> 161 self.tokenize = get_tokenizer(tokenize, tokenizer_language)
#     162 self.include_lengths = include_lengths
#     163 self.batch_first = batch_first
#
# File ~/.local/lib/python3.8/site-packages/torchtext/data/utils.py:124, in get_tokenizer(tokenizer, language)
#     122         import warnings
#     123         warnings.warn(f'Spacy model "{language}" could not be loaded, trying "{OLD_MODEL_SHORTCUTS[language]}" instead')
# --> 124         spacy = spacy.load(OLD_MODEL_SHORTCUTS[language])
#     125     return partial(_spacy_tokenize, spacy=spacy)
#     126 except ImportError:
#
# File ~/.local/lib/python3.8/site-packages/spacy/__init__.py:47, in load(name, disable, exclude, config)
#      29 def load(
#      30     name: Union[str, Path],
#      31     disable: Iterable[str] = util.SimpleFrozenList(),
#      32     exclude: Iterable[str] = util.SimpleFrozenList(),
#      33     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      34 ) -> Language:
#      35     """Load a spaCy model from an installed package or a local path.
#      36
#      37     name (str): Package name or model path.
#    (...)
#      45     RETURNS (Language): The loaded nlp object.
#      46     """
# ---> 47     return util.load_model(name, disable=disable, exclude=exclude, config=config)
#
# File ~/.local/lib/python3.8/site-packages/spacy/util.py:322, in load_model(name, vocab, disable, exclude, config)
#     320     return get_lang_class(name.replace("blank:", ""))()
#     321 if is_package(name):  # installed as package
# --> 322     return load_model_from_package(name, **kwargs)
#     323 if Path(name).exists():  # path to model data directory
#     324     return load_model_from_path(Path(name), **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/spacy/util.py:355, in load_model_from_package(name, vocab, disable, exclude, config)
#     340 """Load a model from an installed package.
#     341
#     342 name (str): The package name.
#    (...)
#     352 RETURNS (Language): The loaded nlp object.
#     353 """
#     354 cls = importlib.import_module(name)
# --> 355 return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)
#
# File ~/.local/lib/python3.8/site-packages/en_core_web_sm/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/.local/lib/python3.8/site-packages/spacy/util.py:514, in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     512 if not model_path.exists():
#     513     raise IOError(Errors.E052.format(path=data_path))
# --> 514 return load_model_from_path(
#     515     data_path,
#     516     vocab=vocab,
#     517     meta=meta,
#     518     disable=disable,
#     519     exclude=exclude,
#     520     config=config,
#     521 )
#
# File ~/.local/lib/python3.8/site-packages/spacy/util.py:389, in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     387 config_path = model_path / "config.cfg"
#     388 config = load_config(config_path, overrides=dict_to_dot(config))
# --> 389 nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     390 return nlp.from_disk(model_path, exclude=exclude)
#
# File ~/.local/lib/python3.8/site-packages/spacy/util.py:426, in load_model_from_config(config, vocab, disable, exclude, auto_fill, validate)
#     423 # This will automatically handle all codes registered via the languages
#     424 # registry, including custom subclasses provided via entry points
#     425 lang_cls = get_lang_class(nlp_config["lang"])
# --> 426 nlp = lang_cls.from_config(
#     427     config,
#     428     vocab=vocab,
#     429     disable=disable,
#     430     exclude=exclude,
#     431     auto_fill=auto_fill,
#     432     validate=validate,
#     433 )
#     434 return nlp
#
# File ~/.local/lib/python3.8/site-packages/spacy/language.py:1650, in Language.from_config(cls, config, vocab, disable, exclude, meta, auto_fill, validate)
#    1647     factory = pipe_cfg.pop("factory")
#    1648     # The pipe name (key in the config) here is the unique name
#    1649     # of the component, not necessarily the factory
# -> 1650     nlp.add_pipe(
#    1651         factory,
#    1652         name=pipe_name,
#    1653         config=pipe_cfg,
#    1654         validate=validate,
#    1655         raw_config=raw_config,
#    1656     )
#    1657 else:
#    1658     model = pipe_cfg["source"]
#
# File ~/.local/lib/python3.8/site-packages/spacy/language.py:767, in Language.add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     759     if not self.has_factory(factory_name):
#     760         err = Errors.E002.format(
#     761             name=factory_name,
#     762             opts=", ".join(self.factory_names),
#    (...)
#     765             lang_code=self.lang,
#     766         )
# --> 767     pipe_component = self.create_pipe(
#     768         factory_name,
#     769         name=name,
#     770         config=config,
#     771         raw_config=raw_config,
#     772         validate=validate,
#     773     )
#     774 pipe_index = self._get_pipe_index(before, after, first, last)
#     775 self._pipe_meta[name] = self.get_factory_meta(factory_name)
#
# File ~/.local/lib/python3.8/site-packages/spacy/language.py:658, in Language.create_pipe(self, factory_name, name, config, raw_config, validate)
#     655 cfg = {factory_name: config}
#     656 # We're calling the internal _fill here to avoid constructing the
#     657 # registered functions twice
# --> 658 resolved = registry.resolve(cfg, validate=validate)
#     659 filled = registry.fill({"cfg": cfg[factory_name]}, validate=validate)["cfg"]
#     660 filled = Config(filled)
#
# File ~/.local/lib/python3.8/site-packages/thinc/config.py:746, in registry.resolve(cls, config, schema, overrides, validate)
#     737 @classmethod
#     738 def resolve(
#     739     cls,
#    (...)
#     744     validate: bool = True,
#     745 ) -> Dict[str, Any]:
# --> 746     resolved, _ = cls._make(
#     747         config, schema=schema, overrides=overrides, validate=validate, resolve=True
#     748     )
#     749     return resolved
#
# File ~/.local/lib/python3.8/site-packages/thinc/config.py:795, in registry._make(cls, config, schema, overrides, resolve, validate)
#     793 if not is_interpolated:
#     794     config = Config(orig_config).interpolate()
# --> 795 filled, _, resolved = cls._fill(
#     796     config, schema, validate=validate, overrides=overrides, resolve=resolve
#     797 )
#     798 filled = Config(filled, section_order=section_order)
#     799 # Check that overrides didn't include invalid properties not in config
#
# File ~/.local/lib/python3.8/site-packages/thinc/config.py:850, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     848     schema.__fields__[key] = copy_model_field(field, Any)
#     849 promise_schema = cls.make_promise_schema(value, resolve=resolve)
# --> 850 filled[key], validation[v_key], final[key] = cls._fill(
#     851     value,
#     852     promise_schema,
#     853     validate=validate,
#     854     resolve=resolve,
#     855     parent=key_parent,
#     856     overrides=overrides,
#     857 )
#     858 reg_name, func_name = cls.get_constructor(final[key])
#     859 args, kwargs = cls.parse_args(final[key])
#
# File ~/.local/lib/python3.8/site-packages/thinc/config.py:849, in registry._fill(cls, config, schema, validate, resolve, parent, overrides)
#     847     field = schema.__fields__[key]
#     848     schema.__fields__[key] = copy_model_field(field, Any)
# --> 849 promise_schema = cls.make_promise_schema(value, resolve=resolve)
#     850 filled[key], validation[v_key], final[key] = cls._fill(
#     851     value,
#     852     promise_schema,
#    (...)
#     856     overrides=overrides,
#     857 )
#     858 reg_name, func_name = cls.get_constructor(final[key])
#
# File ~/.local/lib/python3.8/site-packages/thinc/config.py:1040, in registry.make_promise_schema(cls, obj, resolve)
#    1038 if not resolve and not cls.has(reg_name, func_name):
#    1039     return EmptySchema
# -> 1040 func = cls.get(reg_name, func_name)
#    1041 # Read the argument annotations and defaults from the function signature
#    1042 id_keys = [k for k in obj.keys() if k.startswith("@")]
#
# File ~/.local/lib/python3.8/site-packages/spacy/util.py:128, in registry.get(cls, registry_name, func_name)
#     126 reg = getattr(cls, registry_name)
#     127 try:
# --> 128     func = reg.get(func_name)
#     129 except RegistryError:
#     130     if func_name.startswith("spacy."):
#
# File ~/.local/lib/python3.8/site-packages/catalogue/__init__.py:95, in Registry.get(self, name)
#      93 if not check_exists(*namespace):
#      94     current_namespace = " -> ".join(self.namespace)
# ---> 95     available = ", ".join(sorted(self.get_all().keys())) or "none"
#      96     raise RegistryError(
#      97         f"Cant't find '{name}' in registry {current_namespace}. Available names: {available}"
#      98     )
#      99 return _get(namespace)
#
# File ~/.local/lib/python3.8/site-packages/catalogue/__init__.py:110, in Registry.get_all(self)
#     108 result = {}
#     109 if self.entry_points:
# --> 110     result.update(self.get_entry_points())
#     111 for keys, value in REGISTRY.copy().items():
#     112     if len(self.namespace) == len(keys) - 1 and all(
#     113         self.namespace[i] == keys[i] for i in range(len(self.namespace))
#     114     ):
#
# File ~/.local/lib/python3.8/site-packages/catalogue/__init__.py:125, in Registry.get_entry_points(self)
#     123 result = {}
#     124 for entry_point in self._get_entry_points():
# --> 125     result[entry_point.name] = entry_point.load()
#     126 return result
#
# File ~/.local/lib/python3.8/site-packages/importlib_metadata/__init__.py:191, in EntryPoint.load(self)
#     189 module = import_module(match.group('module'))
#     190 attrs = filter(None, (match.group('attr') or '').split('.'))
# --> 191 return functools.reduce(getattr, attrs, module)
#
# AttributeError: module 'spacy_transformers.architectures' has no attribute 'transformer_tok2vec_v2'
